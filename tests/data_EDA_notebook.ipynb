# %%
import json
import os

# Load JSON data from database files
print("Current Working Directory (CWD):", os.getcwd())
with open('../assets/employees.json') as f:
    employees = json.load(f)
with open('../assets/categories.json') as f:
    categories = json.load(f)
with open('../assets/images.json') as f:
    images = json.load(f)
with open('../assets/keycardentries.json') as f:
    keycard_entries = json.load(f)


print(employees[0].keys())
print(categories[0].keys())
print(images[0].keys())
print(keycard_entries[0].keys())
# Out:
# Current Working Directory (CWD): c:\Users\demen\Documents\FWC_Project\tests
# dict_keys(['EmployeeId', 'FirstName', 'LastName', 'WorkEmail', 'WorkTitle', 'StartDate', 'BirthDate', 'ProfilePictureId', 'IsActive', 'KeyCardId'])
# dict_keys(['categoryId', 'categoryName'])
# dict_keys(['ImageId', 'ImageName', 'ImageExtension', 'ImageData', 'ImageCategoryId'])
# dict_keys(['EntryId', 'EntryDateTime', 'KeyCardId', 'ScannerId', 'EntryCategoryId', 'SecurityImageId'])

# %%
# Search function to find employees by name
def search_employees_by_name(name_query):
    name_query = name_query.lower().strip()
    results = [e for e in employees if name_query
                in (e['FirstName'].lower() + ' ' + e['LastName'].lower())]
    return results

print(search_employees_by_name("Jean"))
print(search_employees_by_name("Jean Mar"))
print(search_employees_by_name("S"))
# Out:
# [{'EmployeeId': 1, 'FirstName': 'Jean', 'LastName': 'Martinez', 'WorkEmail': 'jean_martinez@myfwc.com', 'WorkTitle': 'OPS Associate Research Scientist', 'StartDate': '2022-05-16', 'BirthDate': '1994-11-04', 'ProfilePictureId': 101, 'IsActive': 1, 'KeyCardId': '11111111-1111-1111-1111-111111111111'}]
# [{'EmployeeId': 1, 'FirstName': 'Jean', 'LastName': 'Martinez', 'WorkEmail': 'jean_martinez@myfwc.com', 'WorkTitle': 'OPS Associate Research Scientist', 'StartDate': '2022-05-16', 'BirthDate': '1994-11-04', 'ProfilePictureId': 101, 'IsActive': 1, 'KeyCardId': '11111111-1111-1111-1111-111111111111'}]
# [{'EmployeeId': 4, 'FirstName': 'Omar', 'LastName': 'Sanchez', 'WorkEmail': 'omar_sanchez@myfwc.com', 'WorkTitle': 'Biological Scientist IV', 'StartDate': '2002-06-01', 'BirthDate': '1970-07-12', 'ProfilePictureId': 104, 'IsActive': 1, 'KeyCardId': '44444444-4444-4444-4444-444444444444'}, {'EmployeeId': 5, 'FirstName': 'Mina', 'LastName': 'Kowalski', 'WorkEmail': 'mina_kowalski@myfwc.com', 'WorkTitle': 'Project Coordinator', 'StartDate': '2023-03-03', 'BirthDate': '1998-10-28', 'ProfilePictureId': 105, 'IsActive': 1, 'KeyCardId': '55555555-5555-5555-5555-555555555555'}, {'EmployeeId': 6, 'FirstName': 'Evan', 'LastName': 'Brooks', 'WorkEmail': 'evan_brooks@myfwc.com', 'WorkTitle': 'IT Support', 'StartDate': '2019-02-11', 'BirthDate': '1991-02-19', 'ProfilePictureId': 106, 'IsActive': 1, 'KeyCardId': '66666666-6666-6666-6666-666666666666'}, {'EmployeeId': 8, 'FirstName': 'Hassan', 'LastName': 'Ali', 'WorkEmail': 'hassan_ali@myfwc.com', 'WorkTitle': 'Biological Scientist', 'StartDate': '2020-08-24', 'BirthDate': '1989-09-09', 'ProfilePictureId': 108, 'IsActive': 1, 'KeyCardId': '88888888-8888-8888-8888-888888888888'}, {'EmployeeId': 11, 'FirstName': 'Sofia', 'LastName': 'Mendez', 'WorkEmail': 'sofia_mendez@myfwc.com', 'WorkTitle': 'Intern', 'StartDate': '2025-06-07', 'BirthDate': '2005-12-12', 'ProfilePictureId': 111, 'IsActive': 1, 'KeyCardId': 'bbbbbbbb-bbbb-bbbb-bbbb-bbbbbbbbbbbb'}, {'EmployeeId': 12, 'FirstName': 'Chris', 'LastName': 'Oâ€™Donnell', 'WorkEmail': 'chris_odonnell@myfwc.com', 'WorkTitle': 'Network Systems Administrator', 'StartDate': '2019-09-09', 'BirthDate': '1986-04-22', 'ProfilePictureId': 112, 'IsActive': 1, 'KeyCardId': 'cccccccc-cccc-cccc-cccc-cccccccccccc'}]

# %%
def retrieve_employee_keycard_entries(employee_keyCardId):
    entries = [e for e in keycard_entries if e['KeyCardId'] == employee_keyCardId]
    return entries

print(retrieve_employee_keycard_entries('11111111-1111-1111-1111-111111111111'))
# Out:
# [{'EntryId': 'e0001001-0001-0001-0001-000000000001', 'EntryDateTime': '2025-09-16T08:30:00Z', 'KeyCardId': '11111111-1111-1111-1111-111111111111', 'ScannerId': 'fd001001-fd01-fd01-fd01-fd0000000001', 'EntryCategoryId': 54, 'SecurityImageId': 201}, {'EntryId': 'e0001001-0001-0001-0001-000000000002', 'EntryDateTime': '2025-09-16T12:00:00Z', 'KeyCardId': '11111111-1111-1111-1111-111111111111', 'ScannerId': 'fd001001-fd01-fd01-fd01-fd0000000001', 'EntryCategoryId': 55, 'SecurityImageId': 202}, {'EntryId': 'e0001001-0001-0001-0001-000000000003', 'EntryDateTime': '2025-09-16T12:45:00Z', 'KeyCardId': '11111111-1111-1111-1111-111111111111', 'ScannerId': 'fd001001-fd01-fd01-fd01-fd0000000001', 'EntryCategoryId': 54, 'SecurityImageId': 203}, {'EntryId': 'e0001001-0001-0001-0001-000000000004', 'EntryDateTime': '2025-09-16T17:15:00Z', 'KeyCardId': '11111111-1111-1111-1111-111111111111', 'ScannerId': 'fd001001-fd01-fd01-fd01-fd0000000001', 'EntryCategoryId': 55, 'SecurityImageId': 204}]

# %%
from py_linq import Enumerable

employees_enum = Enumerable(employees)
entries_enum = Enumerable(keycard_entries)
images_enum = Enumerable(images)
categories_enum = Enumerable(categories)

joined_data = employees_enum.join(entries_enum, 
                                  lambda emp: emp['KeyCardId'], 
                                  lambda key: key['KeyCardId'], 
                                  lambda result: {'Employee': result[0], 'KeyCardEntry': result[1]})
print(joined_data)

joined_data_images = joined_data.join(images_enum,
                                      lambda left: left['KeyCardEntry']['SecurityImageId'],
                                      lambda image: image['ImageId'],
                                      lambda result: {'Employee': result[0]['Employee'],
                                                      'KeyCardEntry': result[0]['KeyCardEntry'],
                                                      'Image': result[1]})
print(joined_data_images)

final_data = joined_data_images.join(categories_enum,
                                     lambda left: left['Image']['ImageCategoryId'],
                                     lambda category: category['categoryId'],
                                     lambda result: {'Employee': result[0]['Employee'],
                                                    'KeyCardEntry': result[0]['KeyCardEntry'],
                                                    'Image': result[0]['Image'],
                                                    'Category': result[1]})
print(final_data)
# Out:
# [{'Employee': {'EmployeeId': 1, 'FirstName': 'Jean', 'LastName': 'Martinez', 'WorkEmail': 'jean_martinez@myfwc.com', 'WorkTitle': 'OPS Associate Research Scientist', 'StartDate': '2022-05-16', 'BirthDate': '1994-11-04', 'ProfilePictureId': 101, 'IsActive': 1, 'KeyCardId': '11111111-1111-1111-1111-111111111111'}, 'KeyCardEntry': {'EntryId': 'e0001001-0001-0001-0001-000000000001', 'EntryDateTime': '2025-09-16T08:30:00Z', 'KeyCardId': '11111111-1111-1111-1111-111111111111', 'ScannerId': 'fd001001-fd01-fd01-fd01-fd0000000001', 'EntryCategoryId': 54, 'SecurityImageId': 201}}, {'Employee': {'EmployeeId': 1, 'FirstName': 'Jean', 'LastName': 'Martinez', 'WorkEmail': 'jean_martinez@myfwc.com', 'WorkTitle': 'OPS Associate Research Scientist', 'StartDate': '2022-05-16', 'BirthDate': '1994-11-04', 'ProfilePictureId': 101, 'IsActive': 1, 'KeyCardId': '11111111-1111-1111-1111-111111111111'}, 'KeyCardEntry': {'EntryId': 'e0001001-0001-0001-0001-000000000002', 'EntryDateTime': '2025-09-16T12:00:00Z', 'KeyCardId': '11111111-1111-1111-1111-111111111111', 'ScannerId': 'fd001001-fd01-fd01-fd01-fd0000000001', 'EntryCategoryId': 55, 'SecurityImageId': 202}}, {'Employee': {'EmployeeId': 1, 'FirstName': 'Jean', 'LastName': 'Martinez', 'WorkEmail': 'jean_martinez@myfwc.com', 'WorkTitle': 'OPS Associate Research Scientist', 'StartDate': '2022-05-16', 'BirthDate': '1994-11-04', 'ProfilePictureId': 101, 'IsActive': 1, 'KeyCardId': '11111111-1111-1111-1111-111111111111'}, 'KeyCardEntry': {'EntryId': 'e0001001-0001-0001-0001-000000000003', 'EntryDateTime': '2025-09-16T12:45:00Z', 'KeyCardId': '11111111-1111-1111-1111-111111111111', 'ScannerId': 'fd001001-fd01-fd01-fd01-fd0000000001', 'EntryCategoryId': 54, 'SecurityImageId': 203}}, {'Employee': {'EmployeeId': 1, 'FirstName': 'Jean', 'LastName': 'Martinez', 'WorkEmail': 'jean_martinez@myfwc.com', 'WorkTitle': 'OPS Associate Research Scientist', 'StartDate': '2022-05-16', 'BirthDate': '1994-11-04', 'ProfilePictureId': 101, 'IsActive': 1, 'KeyCardId': '11111111-1111-1111-1111-111111111111'}, 'KeyCardEntry': {'EntryId': 'e0001001-0001-0001-0001-000000000004', 'EntryDateTime': '2025-09-16T17:15:00Z', 'KeyCardId': '11111111-1111-1111-1111-111111111111', 'ScannerId': 'fd001001-fd01-fd01-fd01-fd0000000001', 'EntryCategoryId': 55, 'SecurityImageId': 204}}, {'Employee': {'EmployeeId': 2, 'FirstName': 'Alex', 'LastName': 'Nguyen', 'WorkEmail': 'alex_nguyen@myfwc.com', 'WorkTitle': 'Scientific Programmer', 'StartDate': '2023-01-10', 'BirthDate': '1997-08-21', 'ProfilePictureId': 102, 'IsActive': 1, 'KeyCardId': '22222222-2222-2222-2222-222222222222'}, 'KeyCardEntry': {'EntryId': 'e0001002-0002-0002-0002-000000000001', 'EntryDateTime': '2025-09-16T08:45:00Z', 'KeyCardId': '22222222-2222-2222-2222-222222222222', 'ScannerId': 'fd001002-fd02-fd02-fd02-fd0000000002', 'EntryCategoryId': 54, 'SecurityImageId': 205}}, {'Employee': {'EmployeeId': 2, 'FirstName': 'Alex', 'LastName': 'Nguyen', 'WorkEmail': 'alex_nguyen@myfwc.com', 'WorkTitle': 'Scientific Programmer', 'StartDate': '2023-01-10', 'BirthDate': '1997-08-21', 'ProfilePictureId': 102, 'IsActive': 1, 'KeyCardId': '22222222-2222-2222-2222-222222222222'}, 'KeyCardEntry': {'EntryId': 'e0001002-0002-0002-0002-000000000002', 'EntryDateTime': '2025-09-16T17:30:00Z', 'KeyCardId': '22222222-2222-2222-2222-222222222222', 'ScannerId': 'fd001002-fd02-fd02-fd02-fd0000000002', 'EntryCategoryId': 55, 'SecurityImageId': 206}}, {'Employee': {'EmployeeId': 3, 'FirstName': 'Rina', 'LastName': 'Patel', 'WorkEmail': 'rina_patel@myfwc.com', 'WorkTitle': 'Data Administration Analyst', 'StartDate': '2021-07-12', 'BirthDate': '1996-09-18', 'ProfilePictureId': 103, 'IsActive': 1, 'KeyCardId': '33333333-3333-3333-3333-333333333333'}, 'KeyCardEntry': {'EntryId': 'e0001003-0003-0003-0003-000000000001', 'EntryDateTime': '2025-09-16T09:00:00Z', 'KeyCardId': '33333333-3333-3333-3333-333333333333', 'ScannerId': 'fd001001-fd01-fd01-fd01-fd0000000001', 'EntryCategoryId': 54, 'SecurityImageId': 207}}, { ...
# [{'Employee': {'EmployeeId': 1, 'FirstName': 'Jean', 'LastName': 'Martinez', 'WorkEmail': 'jean_martinez@myfwc.com', 'WorkTitle': 'OPS Associate Research Scientist', 'StartDate': '2022-05-16', 'BirthDate': '1994-11-04', 'ProfilePictureId': 101, 'IsActive': 1, 'KeyCardId': '11111111-1111-1111-1111-111111111111'}, 'KeyCardEntry': {'EntryId': 'e0001001-0001-0001-0001-000000000001', 'EntryDateTime': '2025-09-16T08:30:00Z', 'KeyCardId': '11111111-1111-1111-1111-111111111111', 'ScannerId': 'fd001001-fd01-fd01-fd01-fd0000000001', 'EntryCategoryId': 54, 'SecurityImageId': 201}, 'Image': {'ImageId': 201, 'ImageName': 'SecurityCam_Martinez_20250916_0830', 'ImageExtension': 'jpg', 'ImageData': '/9j/4AAQSkZJRgABAQEAYABgAAD/2wBDAAYEBQYFBAYGBQYHBwYIChAKCgkJChQODwwQFxQYGBcUFhYaHSUfGhsjHBYWICwgIyYnKSopGR8tMC0oMCUoKSj/2wBDAQcHBwoIChMKChMoGhYaKCgoKCgoKCgoKCal', 'ImageCategoryId': 16}}, {'Employee': {'EmployeeId': 1, 'FirstName': 'Jean', 'LastName': 'Martinez', 'WorkEmail': 'jean_martinez@myfwc.com', 'WorkTitle': 'OPS Associate Research Scientist', 'StartDate': '2022-05-16', 'BirthDate': '1994-11-04', 'ProfilePictureId': 101, 'IsActive': 1, 'KeyCardId': '11111111-1111-1111-1111-111111111111'}, 'KeyCardEntry': {'EntryId': 'e0001001-0001-0001-0001-000000000002', 'EntryDateTime': '2025-09-16T12:00:00Z', 'KeyCardId': '11111111-1111-1111-1111-111111111111', 'ScannerId': 'fd001001-fd01-fd01-fd01-fd0000000001', 'EntryCategoryId': 55, 'SecurityImageId': 202}, 'Image': {'ImageId': 202, 'ImageName': 'SecurityCam_Martinez_20250916_1200', 'ImageExtension': 'jpg', 'ImageData': '/9j/4AAQSkZJRgABAQEAYABgAAD/2wBDAAYEBQYFBAYGBQYHBwYIChAKCgkJChQODwwQFxQYGBcUFhYaHSUfGhsjHBYWICwgIyYnKSopGR8tMC0oMCUoKSj/2wBDAQcHBwoIChMKChMoGhYaKCgoKCgoKCgoKCak', 'ImageCategoryId': 16}}, {'Employee': {'EmployeeId': 1, 'FirstName': 'Jean', 'LastName': 'Martinez', 'WorkEmail': 'jean_martinez@myfwc.com', 'WorkTitle': 'OPS Associate Research Scientist', 'StartDate': '2022-05-16', 'BirthDate': '1994-11-04', 'ProfilePictureId': 101, 'IsActive': 1, 'KeyCardId': '11111111-1111-1111-1111-111111111111'}, 'KeyCardEntry': {'EntryId': 'e0001001-0001-0001-0001-000000000003', 'EntryDateTime': '2025-09-16T12:45:00Z', 'KeyCardId': '11111111-1111-1111-1111-111111111111', 'ScannerId': 'fd001001-fd01-fd01-fd01-fd0000000001', 'EntryCategoryId': 54, 'SecurityImageId': 203}, 'Image': {'ImageId': 203, 'ImageName': 'SecurityCam_Martinez_20250916_1245', 'ImageExtension': 'jpg', 'ImageData': '/9j/4AAQSkZJRgABAQEAYABgAAD/2wBDAAYEBQYFBAYGBQYHBwYIChAKCgkJChQODwwQFxQYGBcUFhYaHSUfGhsjHBYWICwgIyYnKSopGR8tMC0oMCUoKSj/2wBDAQcHBwoIChMKChMoGhYaKCgoKCgoKCgoKCaj', 'ImageCategoryId': 16}}, {'Employee': {'EmployeeId': 1, 'FirstName': 'Jean', 'LastName': 'Martinez', 'WorkEmail': 'jean_martinez@myfwc.com', 'WorkTitle': 'OPS Associate Research Scientist', 'StartDate': '2022-05-16', 'BirthDate': '1994-11-04', 'ProfilePictureId': 101, 'IsActive': 1, 'KeyCardId': '11111111-1111-1111-1111-111111111111'}, 'KeyCardEntry': {'EntryId': 'e0001001-0001-0001-0001-000000000004', 'EntryDateTime': '2025-09-16T17:15:00Z', 'KeyCardId': '11111111-1111-1111-1111-111111111111', 'ScannerId': 'fd001001-fd01-fd01-fd01-fd0000000001', 'EntryCategoryId': 55, 'SecurityImageId': 204}, 'Image': {'ImageId': 204, 'ImageName': 'SecurityCam_Martinez_20250916_1715', 'ImageExtension': 'jpg', 'ImageData': '/9j/4AAQSkZJRgABAQEAYABgAAD/2wBDAAYEBQYFBAYGBQYHBwYIChAKCgkJChQODwwQFxQYGBcUFhYaHSUfGhsjHBYWICwgIyYnKSopGR8tMC0oMCUoKSj/2wBDAQcHBwoIChMKChMoGhYaKCgoKCgoKCgoKCai', 'ImageCategoryId': 16}}, {'Employee': {'EmployeeId': 2, 'FirstName': 'Alex', 'LastName': 'Nguyen', 'WorkEmail': 'alex_nguyen@myfwc.com', 'WorkTitle': 'Scientific Programmer', 'StartDate': '2023-01-10', 'BirthDate': '1997-08-21', 'ProfilePictureId': 102, 'IsActive': 1, 'KeyCardId': '22222222-2222-2222-2222-222222222222'}, 'KeyCardEntry': {'EntryId': 'e0001002-0002-0002-0002-000000000001', 'EntryDateTime': '2025-09-16T08:45:00Z', 'KeyCardId': '22222222-2222-2222-2222-222222222222', 'ScannerId': 'fd001 ...
# [{'Employee': {'EmployeeId': 1, 'FirstName': 'Jean', 'LastName': 'Martinez', 'WorkEmail': 'jean_martinez@myfwc.com', 'WorkTitle': 'OPS Associate Research Scientist', 'StartDate': '2022-05-16', 'BirthDate': '1994-11-04', 'ProfilePictureId': 101, 'IsActive': 1, 'KeyCardId': '11111111-1111-1111-1111-111111111111'}, 'KeyCardEntry': {'EntryId': 'e0001001-0001-0001-0001-000000000001', 'EntryDateTime': '2025-09-16T08:30:00Z', 'KeyCardId': '11111111-1111-1111-1111-111111111111', 'ScannerId': 'fd001001-fd01-fd01-fd01-fd0000000001', 'EntryCategoryId': 54, 'SecurityImageId': 201}, 'Image': {'ImageId': 201, 'ImageName': 'SecurityCam_Martinez_20250916_0830', 'ImageExtension': 'jpg', 'ImageData': '/9j/4AAQSkZJRgABAQEAYABgAAD/2wBDAAYEBQYFBAYGBQYHBwYIChAKCgkJChQODwwQFxQYGBcUFhYaHSUfGhsjHBYWICwgIyYnKSopGR8tMC0oMCUoKSj/2wBDAQcHBwoIChMKChMoGhYaKCgoKCgoKCgoKCal', 'ImageCategoryId': 16}, 'Category': {'categoryId': 16, 'categoryName': 'Security Camera Footage'}}, {'Employee': {'EmployeeId': 1, 'FirstName': 'Jean', 'LastName': 'Martinez', 'WorkEmail': 'jean_martinez@myfwc.com', 'WorkTitle': 'OPS Associate Research Scientist', 'StartDate': '2022-05-16', 'BirthDate': '1994-11-04', 'ProfilePictureId': 101, 'IsActive': 1, 'KeyCardId': '11111111-1111-1111-1111-111111111111'}, 'KeyCardEntry': {'EntryId': 'e0001001-0001-0001-0001-000000000002', 'EntryDateTime': '2025-09-16T12:00:00Z', 'KeyCardId': '11111111-1111-1111-1111-111111111111', 'ScannerId': 'fd001001-fd01-fd01-fd01-fd0000000001', 'EntryCategoryId': 55, 'SecurityImageId': 202}, 'Image': {'ImageId': 202, 'ImageName': 'SecurityCam_Martinez_20250916_1200', 'ImageExtension': 'jpg', 'ImageData': '/9j/4AAQSkZJRgABAQEAYABgAAD/2wBDAAYEBQYFBAYGBQYHBwYIChAKCgkJChQODwwQFxQYGBcUFhYaHSUfGhsjHBYWICwgIyYnKSopGR8tMC0oMCUoKSj/2wBDAQcHBwoIChMKChMoGhYaKCgoKCgoKCgoKCak', 'ImageCategoryId': 16}, 'Category': {'categoryId': 16, 'categoryName': 'Security Camera Footage'}}, {'Employee': {'EmployeeId': 1, 'FirstName': 'Jean', 'LastName': 'Martinez', 'WorkEmail': 'jean_martinez@myfwc.com', 'WorkTitle': 'OPS Associate Research Scientist', 'StartDate': '2022-05-16', 'BirthDate': '1994-11-04', 'ProfilePictureId': 101, 'IsActive': 1, 'KeyCardId': '11111111-1111-1111-1111-111111111111'}, 'KeyCardEntry': {'EntryId': 'e0001001-0001-0001-0001-000000000003', 'EntryDateTime': '2025-09-16T12:45:00Z', 'KeyCardId': '11111111-1111-1111-1111-111111111111', 'ScannerId': 'fd001001-fd01-fd01-fd01-fd0000000001', 'EntryCategoryId': 54, 'SecurityImageId': 203}, 'Image': {'ImageId': 203, 'ImageName': 'SecurityCam_Martinez_20250916_1245', 'ImageExtension': 'jpg', 'ImageData': '/9j/4AAQSkZJRgABAQEAYABgAAD/2wBDAAYEBQYFBAYGBQYHBwYIChAKCgkJChQODwwQFxQYGBcUFhYaHSUfGhsjHBYWICwgIyYnKSopGR8tMC0oMCUoKSj/2wBDAQcHBwoIChMKChMoGhYaKCgoKCgoKCgoKCaj', 'ImageCategoryId': 16}, 'Category': {'categoryId': 16, 'categoryName': 'Security Camera Footage'}}, {'Employee': {'EmployeeId': 1, 'FirstName': 'Jean', 'LastName': 'Martinez', 'WorkEmail': 'jean_martinez@myfwc.com', 'WorkTitle': 'OPS Associate Research Scientist', 'StartDate': '2022-05-16', 'BirthDate': '1994-11-04', 'ProfilePictureId': 101, 'IsActive': 1, 'KeyCardId': '11111111-1111-1111-1111-111111111111'}, 'KeyCardEntry': {'EntryId': 'e0001001-0001-0001-0001-000000000004', 'EntryDateTime': '2025-09-16T17:15:00Z', 'KeyCardId': '11111111-1111-1111-1111-111111111111', 'ScannerId': 'fd001001-fd01-fd01-fd01-fd0000000001', 'EntryCategoryId': 55, 'SecurityImageId': 204}, 'Image': {'ImageId': 204, 'ImageName': 'SecurityCam_Martinez_20250916_1715', 'ImageExtension': 'jpg', 'ImageData': '/9j/4AAQSkZJRgABAQEAYABgAAD/2wBDAAYEBQYFBAYGBQYHBwYIChAKCgkJChQODwwQFxQYGBcUFhYaHSUfGhsjHBYWICwgIyYnKSopGR8tMC0oMCUoKSj/2wBDAQcHBwoIChMKChMoGhYaKCgoKCgoKCgoKCai', 'ImageCategoryId': 16}, 'Category': {'categoryId': 16, 'categoryName': 'Security Camera Footage'}}, {'Employee': {'EmployeeId': 2, 'FirstName': 'Alex', 'LastName': 'Nguyen', 'WorkEmail': 'alex_nguyen@myfwc.com', 'WorkTitle': 'Scientific Programmer', 'StartDate': '2023-01-10', 'B ...

# %%
def retrieve_information_by_name(name_query):
    name_query = name_query.lower().strip()
    results = (final_data
               .where(lambda entry: name_query in (entry['Employee']['FirstName'].lower() + ' ' + entry['Employee']['LastName'].lower())))
    return results

print(retrieve_information_by_name("Omar"))
# Out:
# [{'Employee': {'EmployeeId': 4, 'FirstName': 'Omar', 'LastName': 'Sanchez', 'WorkEmail': 'omar_sanchez@myfwc.com', 'WorkTitle': 'Biological Scientist IV', 'StartDate': '2002-06-01', 'BirthDate': '1970-07-12', 'ProfilePictureId': 104, 'IsActive': 1, 'KeyCardId': '44444444-4444-4444-4444-444444444444'}, 'KeyCardEntry': {'EntryId': 'e0001004-0004-0004-0004-000000000001', 'EntryDateTime': '2025-09-16T08:00:00Z', 'KeyCardId': '44444444-4444-4444-4444-444444444444', 'ScannerId': 'fd001002-fd02-fd02-fd02-fd0000000002', 'EntryCategoryId': 54, 'SecurityImageId': 211}, 'Image': {'ImageId': 211, 'ImageName': 'SecurityCam_Sanchez_20250916_0800', 'ImageExtension': 'jpg', 'ImageData': '/9j/4AAQSkZJRgABAQEAYABgAAD/2wBDAAYEBQYFBAYGBQYHBwYIChAKCgkJChQODwwQFxQYGBcUFhYaHSUfGhsjHBYWICwgIyYnKSopGR8tMC0oMCUoKSj/2wBDAQcHBwoIChMKChMoGhYaKCgoKCgoKCgoKCab', 'ImageCategoryId': 16}, 'Category': {'categoryId': 16, 'categoryName': 'Security Camera Footage'}}, {'Employee': {'EmployeeId': 4, 'FirstName': 'Omar', 'LastName': 'Sanchez', 'WorkEmail': 'omar_sanchez@myfwc.com', 'WorkTitle': 'Biological Scientist IV', 'StartDate': '2002-06-01', 'BirthDate': '1970-07-12', 'ProfilePictureId': 104, 'IsActive': 1, 'KeyCardId': '44444444-4444-4444-4444-444444444444'}, 'KeyCardEntry': {'EntryId': 'e0001004-0004-0004-0004-000000000002', 'EntryDateTime': '2025-09-16T16:30:00Z', 'KeyCardId': '44444444-4444-4444-4444-444444444444', 'ScannerId': 'fd001002-fd02-fd02-fd02-fd0000000002', 'EntryCategoryId': 55, 'SecurityImageId': 212}, 'Image': {'ImageId': 212, 'ImageName': 'SecurityCam_Sanchez_20250916_1630', 'ImageExtension': 'jpg', 'ImageData': '/9j/4AAQSkZJRgABAQEAYABgAAD/2wBDAAYEBQYFBAYGBQYHBwYIChAKCgkJChQODwwQFxQYGBcUFhYaHSUfGhsjHBYWICwgIyYnKSopGR8tMC0oMCUoKSj/2wBDAQcHBwoIChMKChMoGhYaKCgoKCgoKCgoKCaa', 'ImageCategoryId': 16}, 'Category': {'categoryId': 16, 'categoryName': 'Security Camera Footage'}}]

# %%
from datetime import datetime
DATE_FORMAT = "%Y-%m-%dT%H:%M:%SZ"
def retrieve_information_by_date_range(start_date, end_date):

    if isinstance(start_date, str):
        start_date = datetime.strptime(start_date, DATE_FORMAT)
    if isinstance(end_date, str):
        end_date = datetime.strptime(end_date, DATE_FORMAT)

    if start_date and not end_date or not start_date and end_date:
        end_date = start_date

    results = (final_data
               .where(lambda entry: start_date <= datetime.strptime(entry['KeyCardEntry']['EntryDateTime'],DATE_FORMAT) <= end_date))
    return results

print(retrieve_information_by_date_range(datetime.strptime("2025-09-16T08:00:00Z", DATE_FORMAT), datetime.strptime("2025-09-16T10:00:00Z", DATE_FORMAT)))
# Out:
# [{'Employee': {'EmployeeId': 1, 'FirstName': 'Jean', 'LastName': 'Martinez', 'WorkEmail': 'jean_martinez@myfwc.com', 'WorkTitle': 'OPS Associate Research Scientist', 'StartDate': '2022-05-16', 'BirthDate': '1994-11-04', 'ProfilePictureId': 101, 'IsActive': 1, 'KeyCardId': '11111111-1111-1111-1111-111111111111'}, 'KeyCardEntry': {'EntryId': 'e0001001-0001-0001-0001-000000000001', 'EntryDateTime': '2025-09-16T08:30:00Z', 'KeyCardId': '11111111-1111-1111-1111-111111111111', 'ScannerId': 'fd001001-fd01-fd01-fd01-fd0000000001', 'EntryCategoryId': 54, 'SecurityImageId': 201}, 'Image': {'ImageId': 201, 'ImageName': 'SecurityCam_Martinez_20250916_0830', 'ImageExtension': 'jpg', 'ImageData': '/9j/4AAQSkZJRgABAQEAYABgAAD/2wBDAAYEBQYFBAYGBQYHBwYIChAKCgkJChQODwwQFxQYGBcUFhYaHSUfGhsjHBYWICwgIyYnKSopGR8tMC0oMCUoKSj/2wBDAQcHBwoIChMKChMoGhYaKCgoKCgoKCgoKCal', 'ImageCategoryId': 16}, 'Category': {'categoryId': 16, 'categoryName': 'Security Camera Footage'}}, {'Employee': {'EmployeeId': 2, 'FirstName': 'Alex', 'LastName': 'Nguyen', 'WorkEmail': 'alex_nguyen@myfwc.com', 'WorkTitle': 'Scientific Programmer', 'StartDate': '2023-01-10', 'BirthDate': '1997-08-21', 'ProfilePictureId': 102, 'IsActive': 1, 'KeyCardId': '22222222-2222-2222-2222-222222222222'}, 'KeyCardEntry': {'EntryId': 'e0001002-0002-0002-0002-000000000001', 'EntryDateTime': '2025-09-16T08:45:00Z', 'KeyCardId': '22222222-2222-2222-2222-222222222222', 'ScannerId': 'fd001002-fd02-fd02-fd02-fd0000000002', 'EntryCategoryId': 54, 'SecurityImageId': 205}, 'Image': {'ImageId': 205, 'ImageName': 'SecurityCam_Nguyen_20250916_0845', 'ImageExtension': 'jpg', 'ImageData': '/9j/4AAQSkZJRgABAQEAYABgAAD/2wBDAAYEBQYFBAYGBQYHBwYIChAKCgkJChQODwwQFxQYGBcUFhYaHSUfGhsjHBYWICwgIyYnKSopGR8tMC0oMCUoKSj/2wBDAQcHBwoIChMKChMoGhYaKCgoKCgoKCgoKCah', 'ImageCategoryId': 16}, 'Category': {'categoryId': 16, 'categoryName': 'Security Camera Footage'}}, {'Employee': {'EmployeeId': 3, 'FirstName': 'Rina', 'LastName': 'Patel', 'WorkEmail': 'rina_patel@myfwc.com', 'WorkTitle': 'Data Administration Analyst', 'StartDate': '2021-07-12', 'BirthDate': '1996-09-18', 'ProfilePictureId': 103, 'IsActive': 1, 'KeyCardId': '33333333-3333-3333-3333-333333333333'}, 'KeyCardEntry': {'EntryId': 'e0001003-0003-0003-0003-000000000001', 'EntryDateTime': '2025-09-16T09:00:00Z', 'KeyCardId': '33333333-3333-3333-3333-333333333333', 'ScannerId': 'fd001001-fd01-fd01-fd01-fd0000000001', 'EntryCategoryId': 54, 'SecurityImageId': 207}, 'Image': {'ImageId': 207, 'ImageName': 'SecurityCam_Patel_20250916_0900', 'ImageExtension': 'jpg', 'ImageData': '/9j/4AAQSkZJRgABAQEAYABgAAD/2wBDAAYEBQYFBAYGBQYHBwYIChAKCgkJChQODwwQFxQYGBcUFhYaHSUfGhsjHBYWICwgIyYnKSopGR8tMC0oMCUoKSj/2wBDAQcHBwoIChMKChMoGhYaKCgoKCgoKCgoKCaf', 'ImageCategoryId': 16}, 'Category': {'categoryId': 16, 'categoryName': 'Security Camera Footage'}}, {'Employee': {'EmployeeId': 4, 'FirstName': 'Omar', 'LastName': 'Sanchez', 'WorkEmail': 'omar_sanchez@myfwc.com', 'WorkTitle': 'Biological Scientist IV', 'StartDate': '2002-06-01', 'BirthDate': '1970-07-12', 'ProfilePictureId': 104, 'IsActive': 1, 'KeyCardId': '44444444-4444-4444-4444-444444444444'}, 'KeyCardEntry': {'EntryId': 'e0001004-0004-0004-0004-000000000001', 'EntryDateTime': '2025-09-16T08:00:00Z', 'KeyCardId': '44444444-4444-4444-4444-444444444444', 'ScannerId': 'fd001002-fd02-fd02-fd02-fd0000000002', 'EntryCategoryId': 54, 'SecurityImageId': 211}, 'Image': {'ImageId': 211, 'ImageName': 'SecurityCam_Sanchez_20250916_0800', 'ImageExtension': 'jpg', 'ImageData': '/9j/4AAQSkZJRgABAQEAYABgAAD/2wBDAAYEBQYFBAYGBQYHBwYIChAKCgkJChQODwwQFxQYGBcUFhYaHSUfGhsjHBYWICwgIyYnKSopGR8tMC0oMCUoKSj/2wBDAQcHBwoIChMKChMoGhYaKCgoKCgoKCgoKCab', 'ImageCategoryId': 16}, 'Category': {'categoryId': 16, 'categoryName': 'Security Camera Footage'}}, {'Employee': {'EmployeeId': 5, 'FirstName': 'Mina', 'LastName': 'Kowalski', 'WorkEmail': 'mina_kowalski@myfwc.com', 'WorkTitle': 'Project Coordinator', 'StartDate': '2023-03-03', 'BirthDate': '1998-10-28', 'ProfilePictureI ...

# %%
def retrieve_information_by_both(name_query, start_date, end_date):
    name_query = name_query.lower().strip()
    DATE_FORMAT = "%Y-%m-%dT%H:%M:%SZ"
    results = (final_data
               .where(lambda entry: name_query in (entry['Employee']['FirstName'].lower() + ' ' + entry['Employee']['LastName'].lower()) and
                                  start_date <= datetime.strptime(entry['KeyCardEntry']['EntryDateTime'],DATE_FORMAT) <= end_date))
    return results
print(retrieve_information_by_both("Omar", datetime.strptime("2025-09-16T08:00:00Z", DATE_FORMAT), datetime.strptime("2025-09-16T10:00:00Z", DATE_FORMAT)))
# Out:
# [{'Employee': {'EmployeeId': 4, 'FirstName': 'Omar', 'LastName': 'Sanchez', 'WorkEmail': 'omar_sanchez@myfwc.com', 'WorkTitle': 'Biological Scientist IV', 'StartDate': '2002-06-01', 'BirthDate': '1970-07-12', 'ProfilePictureId': 104, 'IsActive': 1, 'KeyCardId': '44444444-4444-4444-4444-444444444444'}, 'KeyCardEntry': {'EntryId': 'e0001004-0004-0004-0004-000000000001', 'EntryDateTime': '2025-09-16T08:00:00Z', 'KeyCardId': '44444444-4444-4444-4444-444444444444', 'ScannerId': 'fd001002-fd02-fd02-fd02-fd0000000002', 'EntryCategoryId': 54, 'SecurityImageId': 211}, 'Image': {'ImageId': 211, 'ImageName': 'SecurityCam_Sanchez_20250916_0800', 'ImageExtension': 'jpg', 'ImageData': '/9j/4AAQSkZJRgABAQEAYABgAAD/2wBDAAYEBQYFBAYGBQYHBwYIChAKCgkJChQODwwQFxQYGBcUFhYaHSUfGhsjHBYWICwgIyYnKSopGR8tMC0oMCUoKSj/2wBDAQcHBwoIChMKChMoGhYaKCgoKCgoKCgoKCab', 'ImageCategoryId': 16}, 'Category': {'categoryId': 16, 'categoryName': 'Security Camera Footage'}}]

# %%
def retrieve_information(name_query = None, start_date = None, end_date = None):
    results = final_data
    if name_query:
        if start_date and end_date:
            results = retrieve_information_by_both(name_query, start_date, end_date)
        if start_date and not end_date:
            results = retrieve_information_by_both(name_query, start_date, datetime.max)
        if not start_date and end_date:
            results = retrieve_information_by_both(name_query, datetime.min, end_date)
        if not start_date and not end_date:
            results = retrieve_information_by_name(name_query)
    else:
        if start_date and end_date:
            results = retrieve_information_by_date_range(start_date, end_date)
        if start_date and not end_date:
            results = retrieve_information_by_date_range(start_date, datetime.max)
        if not start_date and end_date:
            results = retrieve_information_by_date_range(datetime.min, end_date)
    return results.to_list()

print(retrieve_information(name_query="Omar", start_date=datetime.strptime("2025-09-16T08:00:00Z", DATE_FORMAT), end_date=datetime.strptime("2025-09-16T10:00:00Z", DATE_FORMAT)))
# Out:
# [{'Employee': {'EmployeeId': 4, 'FirstName': 'Omar', 'LastName': 'Sanchez', 'WorkEmail': 'omar_sanchez@myfwc.com', 'WorkTitle': 'Biological Scientist IV', 'StartDate': '2002-06-01', 'BirthDate': '1970-07-12', 'ProfilePictureId': 104, 'IsActive': 1, 'KeyCardId': '44444444-4444-4444-4444-444444444444'}, 'KeyCardEntry': {'EntryId': 'e0001004-0004-0004-0004-000000000001', 'EntryDateTime': '2025-09-16T08:00:00Z', 'KeyCardId': '44444444-4444-4444-4444-444444444444', 'ScannerId': 'fd001002-fd02-fd02-fd02-fd0000000002', 'EntryCategoryId': 54, 'SecurityImageId': 211}, 'Image': {'ImageId': 211, 'ImageName': 'SecurityCam_Sanchez_20250916_0800', 'ImageExtension': 'jpg', 'ImageData': '/9j/4AAQSkZJRgABAQEAYABgAAD/2wBDAAYEBQYFBAYGBQYHBwYIChAKCgkJChQODwwQFxQYGBcUFhYaHSUfGhsjHBYWICwgIyYnKSopGR8tMC0oMCUoKSj/2wBDAQcHBwoIChMKChMoGhYaKCgoKCgoKCgoKCab', 'ImageCategoryId': 16}, 'Category': {'categoryId': 16, 'categoryName': 'Security Camera Footage'}}]

# %%
import pandas as pd

final_data_list = final_data.to_list()
df = pd.json_normalize(
    final_data_list,
    sep='_',
    max_level=2 
)
df.columns = [
    col.split('_', 1)[-1] 
    for col in df.columns
]
display(df)  # Display the first few rows of the DataFrame
# Out:
#     EmployeeId FirstName     LastName                 WorkEmail  \
# 0            1      Jean     Martinez   jean_martinez@myfwc.com
# 1            1      Jean     Martinez   jean_martinez@myfwc.com
# 2            1      Jean     Martinez   jean_martinez@myfwc.com
# 3            1      Jean     Martinez   jean_martinez@myfwc.com
# 4            2      Alex       Nguyen     alex_nguyen@myfwc.com
# 5            2      Alex       Nguyen     alex_nguyen@myfwc.com
# 6            3      Rina        Patel      rina_patel@myfwc.com
# 7            3      Rina        Patel      rina_patel@myfwc.com
# 8            3      Rina        Patel      rina_patel@myfwc.com
# 9            3      Rina        Patel      rina_patel@myfwc.com
# 10           4      Omar      Sanchez    omar_sanchez@myfwc.com
# 11           4      Omar      Sanchez    omar_sanchez@myfwc.com
# 12           5      Mina     Kowalski   mina_kowalski@myfwc.com
# 13           5      Mina     Kowalski   mina_kowalski@myfwc.com
# 14           5      Mina     Kowalski   mina_kowalski@myfwc.com
# 15           5      Mina     Kowalski   mina_kowalski@myfwc.com
# 16           6      Evan       Brooks     evan_brooks@myfwc.com
# 17           6      Evan       Brooks     evan_brooks@myfwc.com
# 18           7      Tara          Lee        tara_lee@myfwc.com
# 19           7      Tara          Lee        tara_lee@myfwc.com
# 20           7      Tara          Lee        tara_lee@myfwc.com
# 21           7      Tara          Lee        tara_lee@myfwc.com
# 22           8    Hassan          Ali      hassan_ali@myfwc.com
# 23           8    Hassan          Ali      hassan_ali@myfwc.com
# 24           8    Hassan          Ali      hassan_ali@myfwc.com
# 25           8    Hassan          Ali      hassan_ali@myfwc.com
# 26           9     Laura          Kim       laura_kim@myfwc.com
# 27           9     Laura          Kim       laura_kim@myfwc.com
# 28          10     Riley         Chen      riley_chen@myfwc.com
# 29          10     Riley         Chen      riley_chen@myfwc.com
# 30          10     Riley         Chen      riley_chen@myfwc.com
# 31          10     Riley         Chen      riley_chen@myfwc.com
# 32          11     Sofia       Mendez    sofia_mendez@myfwc.com
# 33          11     Sofia       Mendez    sofia_mendez@myfwc.com
# 34          12     Chris  Oâ€™Donnell  chris_odonnell@myfwc.com
# 35          12     Chris  Oâ€™Donnell  chris_odonnell@myfwc.com
# 36          12     Chris  Oâ€™Donnell  chris_odonnell@myfwc.com
# 37          12     Chris  Oâ€™Donnell  chris_odonnell@myfwc.com
# 38          13     Nadia        Brown     nadia_brown@myfwc.com
# 39          13     Nadia        Brown     nadia_brown@myfwc.com
# 40          14       Ken     Yamamoto    ken_yamamoto@myfwc.com
# 41          14       Ken     Yamamoto    ken_yamamoto@myfwc.com
# 42          14       Ken     Yamamoto    ken_yamamoto@myfwc.com
# 43          14       Ken     Yamamoto    ken_yamamoto@myfwc.com
# 44          15     Grace        Lopez     grace_lopez@myfwc.com
# 45          15     Grace        Lopez     grace_lopez@myfwc.com
# 46          15     Grace        Lopez     grace_lopez@myfwc.com
# 47          15     Grace        Lopez     grace_lopez@myfwc.com
#
#                            WorkTitle   StartDate   BirthDate  \
# 0   OPS Associate Research Scientist  2022-05-16  1994-11-04
# 1   OPS Associate Research Scientist  2022-05-16  1994-11-04
# 2   OPS Associate Research Scientist  2022-05-16  1994-11-04
# 3   OPS Associate Research Scientist  2022-05-16  1994-11-04
# 4              Scientific Programmer  2023-01-10  1997-08-21
# 5              Scientific Programmer  2023-01-10  1997-08-21
# 6        Data Administration Analyst  2021-07-12  1996-09-18
# 7        Data Administration Analyst  2021-07-12  1996-09-18
# 8        Data Administration Analyst  2021-07-12  1996-09-18
# 9        Data Administration Analyst  2021-07-12  1996-09-18
# 10           Biological Scientist IV  2002-06-01  1970-07-12
# 11           Biological Scientist IV  2002-06-01  1970-07-12
# 12               Project Coordinator  2023-03-03  1998-10-28
# 13               Project Coordinator  2023-03-03  1998-10-28
# 14               Project Coordinator  2023-03-03  1998-10-28
# 15               Project Coordinator  2023-03-03  1998-10-28
# 16                        IT Support  2019-02-11  1991-02-19
# 17                        IT Support  2019-02-11  1991-02-19
# 18           Biological Scientist II  2021-11-09  1995-01-30
# 19           Biological Scientist II  2021-11-09  1995-01-30
# 20           Biological Scientist II  2021-11-09  1995-01-30
# 21           Biological Scientist II  2021-11-09  1995-01-30
# 22              Biological Scientist  2020-08-24  1989-09-09
# 23              Biological Scientist  2020-08-24  1989-09-09
# 24              Biological Scientist  2020-08-24  1989-09-09
# 25              Biological Scientist  2020-08-24  1989-09-09
# 26              Biological Scientist  2018-10-15  1988-05-25
# 27              Biological Scientist  2018-10-15  1988-05-25
# 28         Research Administrator II  2021-02-12  1975-09-18
# 29         Research Administrator II  2021-02-12  1975-09-18
# 30         Research Administrator II  2021-02-12  1975-09-18
# 31         Research Administrator II  2021-02-12  1975-09-18
# 32                            Intern  2025-06-07  2005-12-12
# 33                            Intern  2025-06-07  2005-12-12
# 34     Network Systems Administrator  2019-09-09  1986-04-22
# 35     Network Systems Administrator  2019-09-09  1986-04-22
# 36     Network Systems Administrator  2019-09-09  1986-04-22
# 37     Network Systems Administrator  2019-09-09  1986-04-22
# 38                    Data Scientist  2023-07-17  1996-09-02
# 39                    Data Scientist  2023-07-17  1996-09-02
# 40              Biological Scientist  2017-03-13  1985-03-30
# 41              Biological Scientist  2017-03-13  1985-03-30
# 42              Biological Scientist  2017-03-13  1985-03-30
# 43              Biological Scientist  2017-03-13  1985-03-30
# 44         Management Analyst Senior  2020-04-20  1991-01-09
# 45         Management Analyst Senior  2020-04-20  1991-01-09
# 46         Management Analyst Senior  2020-04-20  1991-01-09
# 47         Management Analyst Senior  2020-04-20  1991-01-09
#
#     ProfilePictureId  IsActive                             KeyCardId  ...  \
# 0                101         1  11111111-1111-1111-1111-111111111111  ...
# 1                101         1  11111111-1111-1111-1111-111111111111  ...
# 2                101         1  11111111-1111-1111-1111-111111111111  ...
# 3                101         1  11111111-1111-1111-1111-111111111111  ...
# 4                102         1  22222222-2222-2222-2222-222222222222  ...
# 5                102         1  22222222-2222-2222-2222-222222222222  ...
# 6                103         1  33333333-3333-3333-3333-333333333333  ...
# 7                103         1  33333333-3333-3333-3333-333333333333  ...
# 8                103         1  33333333-3333-3333-3333-333333333333  ...
# 9                103         1  33333333-3333-3333-3333-333333333333  ...
# 10               104         1  44444444-4444-4444-4444-444444444444  ...
# 11               104         1  44444444-4444-4444-4444-444444444444  ...
# 12               105         1  55555555-5555-5555-5555-555555555555  ...
# 13               105         1  55555555-5555-5555-5555-555555555555  ...
# 14               105         1  55555555-5555-5555-5555-555555555555  ...
# 15               105         1  55555555-5555-5555-5555-555555555555  ...
# 16               106         1  66666666-6666-6666-6666-666666666666  ...
# 17               106         1  66666666-6666-6666-6666-666666666666  ...
# 18               107         1  77777777-7777-7777-7777-777777777777  ...
# 19               107         1  77777777-7777-7777-7777-777777777777  ...
# 20               107         1  77777777-7777-7777-7777-777777777777  ...
# 21               107         1  77777777-7777-7777-7777-777777777777  ...
# 22               108         1  88888888-8888-8888-8888-888888888888  ...
# 23               108         1  88888888-8888-8888-8888-888888888888  ...
# 24               108         1  88888888-8888-8888-8888-888888888888  ...
# 25               108         1  88888888-8888-8888-8888-888888888888  ...
# 26               109         1  99999999-9999-9999-9999-999999999999  ...
# 27               109         1  99999999-9999-9999-9999-999999999999  ...
# 28               110         1  aaaaaaaa-aaaa-aaaa-aaaa-aaaaaaaaaaaa  ...
# 29               110         1  aaaaaaaa-aaaa-aaaa-aaaa-aaaaaaaaaaaa  ...
# 30               110         1  aaaaaaaa-aaaa-aaaa-aaaa-aaaaaaaaaaaa  ...
# 31               110         1  aaaaaaaa-aaaa-aaaa-aaaa-aaaaaaaaaaaa  ...
# 32               111         1  bbbbbbbb-bbbb-bbbb-bbbb-bbbbbbbbbbbb  ...
# 33               111         1  bbbbbbbb-bbbb-bbbb-bbbb-bbbbbbbbbbbb  ...
# 34               112         1  cccccccc-cccc-cccc-cccc-cccccccccccc  ...
# 35               112         1  cccccccc-cccc-cccc-cccc-cccccccccccc  ...
# 36               112         1  cccccccc-cccc-cccc-cccc-cccccccccccc  ...
# 37               112         1  cccccccc-cccc-cccc-cccc-cccccccccccc  ...
# 38               113         1  dddddddd-dddd-dddd-dddd-dddddddddddd  ...
# 39               113         1  dddddddd-dddd-dddd-dddd-dddddddddddd  ...
# 40               114         1  eeeeeeee-eeee-eeee-eeee-eeeeeeeeeeee  ...
# 41               114         1  eeeeeeee-eeee-eeee-eeee-eeeeeeeeeeee  ...
# 42               114         1  eeeeeeee-eeee-eeee-eeee-eeeeeeeeeeee  ...
# 43               114         1  eeeeeeee-eeee-eeee-eeee-eeeeeeeeeeee  ...
# 44               115         1  ffffffff-ffff-ffff-ffff-ffffffffffff  ...
# 45               115         1  ffffffff-ffff-ffff-ffff-ffffffffffff  ...
# 46               115         1  ffffffff-ffff-ffff-ffff-ffffffffffff  ...
# 47               115         1  ffffffff-ffff-ffff-ffff-ffffffffffff  ...
#
#                                ScannerId EntryCategoryId SecurityImageId  \
# 0   fd001001-fd01-fd01-fd01-fd0000000001              54             201
# 1   fd001001-fd01-fd01-fd01-fd0000000001              55             202
# 2   fd001001-fd01-fd01-fd01-fd0000000001              54             203
# 3   fd001001-fd01-fd01-fd01-fd0000000001              55             204
# 4   fd001002-fd02-fd02-fd02-fd0000000002              54             205
# 5   fd001002-fd02-fd02-fd02-fd0000000002              55             206
# 6   fd001001-fd01-fd01-fd01-fd0000000001              54             207
# 7   fd001001-fd01-fd01-fd01-fd0000000001              55             208
# 8   fd001001-fd01-fd01-fd01-fd0000000001              54             209
# 9   fd001001-fd01-fd01-fd01-fd0000000001              55             210
# 10  fd001002-fd02-fd02-fd02-fd0000000002              54             211
# 11  fd001002-fd02-fd02-fd02-fd0000000002              55             212
# 12  fd001001-fd01-fd01-fd01-fd0000000001              54             213
# 13  fd001001-fd01-fd01-fd01-fd0000000001              55             214
# 14  fd001001-fd01-fd01-fd01-fd0000000001              54             215
# 15  fd001001-fd01-fd01-fd01-fd0000000001              55             216
# 16  fd001002-fd02-fd02-fd02-fd0000000002              54             217
# 17  fd001002-fd02-fd02-fd02-fd0000000002              55             218
# 18  fd001001-fd01-fd01-fd01-fd0000000001              54             219
# 19  fd001001-fd01-fd01-fd01-fd0000000001              55             220
# 20  fd001001-fd01-fd01-fd01-fd0000000001              54             221
# 21  fd001001-fd01-fd01-fd01-fd0000000001              55             222
# 22  fd001002-fd02-fd02-fd02-fd0000000002              54             223
# 23  fd001002-fd02-fd02-fd02-fd0000000002              55             224
# 24  fd001002-fd02-fd02-fd02-fd0000000002              54             225
# 25  fd001002-fd02-fd02-fd02-fd0000000002              55             226
# 26  fd001001-fd01-fd01-fd01-fd0000000001              54             227
# 27  fd001001-fd01-fd01-fd01-fd0000000001              55             228
# 28  fd001002-fd02-fd02-fd02-fd0000000002              54             229
# 29  fd001002-fd02-fd02-fd02-fd0000000002              55             230
# 30  fd001002-fd02-fd02-fd02-fd0000000002              54             231
# 31  fd001002-fd02-fd02-fd02-fd0000000002              55             232
# 32  fd001001-fd01-fd01-fd01-fd0000000001              54             233
# 33  fd001001-fd01-fd01-fd01-fd0000000001              55             234
# 34  fd001002-fd02-fd02-fd02-fd0000000002              54             235
# 35  fd001002-fd02-fd02-fd02-fd0000000002              55             236
# 36  fd001002-fd02-fd02-fd02-fd0000000002              54             237
# 37  fd001002-fd02-fd02-fd02-fd0000000002              55             238
# 38  fd001001-fd01-fd01-fd01-fd0000000001              54             239
# 39  fd001001-fd01-fd01-fd01-fd0000000001              55             240
# 40  fd001002-fd02-fd02-fd02-fd0000000002              54             241
# 41  fd001002-fd02-fd02-fd02-fd0000000002              55             242
# 42  fd001002-fd02-fd02-fd02-fd0000000002              54             243
# 43  fd001002-fd02-fd02-fd02-fd0000000002              55             244
# 44  fd001001-fd01-fd01-fd01-fd0000000001              54             245
# 45  fd001001-fd01-fd01-fd01-fd0000000001              55             246
# 46  fd001001-fd01-fd01-fd01-fd0000000001              54             247
# 47  fd001001-fd01-fd01-fd01-fd0000000001              55             248
#
#    ImageId                           ImageName  ImageExtension  \
# 0      201  SecurityCam_Martinez_20250916_0830             jpg
# 1      202  SecurityCam_Martinez_20250916_1200             jpg
# 2      203  SecurityCam_Martinez_20250916_1245             jpg
# 3      204  SecurityCam_Martinez_20250916_1715             jpg
# 4      205    SecurityCam_Nguyen_20250916_0845             jpg
# 5      206    SecurityCam_Nguyen_20250916_1730             jpg
# 6      207     SecurityCam_Patel_20250916_0900             jpg
# 7      208     SecurityCam_Patel_20250916_1200             jpg
# 8      209     SecurityCam_Patel_20250916_1300             jpg
# 9      210     SecurityCam_Patel_20250916_1800             jpg
# 10     211   SecurityCam_Sanchez_20250916_0800             jpg
# 11     212   SecurityCam_Sanchez_20250916_1630             jpg
# 12     213  SecurityCam_Kowalski_20250916_0915             jpg
# 13     214  SecurityCam_Kowalski_20250916_1145             jpg
# 14     215  SecurityCam_Kowalski_20250916_1330             jpg
# 15     216  SecurityCam_Kowalski_20250916_1745             jpg
# 16     217    SecurityCam_Brooks_20250916_0820             jpg
# 17     218    SecurityCam_Brooks_20250916_1700             jpg
# 18     219       SecurityCam_Lee_20250916_0930             jpg
# 19     220       SecurityCam_Lee_20250916_1230             jpg
# 20     221       SecurityCam_Lee_20250916_1315             jpg
# 21     222       SecurityCam_Lee_20250916_1800             jpg
# 22     223       SecurityCam_Ali_20250916_0815             jpg
# 23     224       SecurityCam_Ali_20250916_1215             jpg
# 24     225       SecurityCam_Ali_20250916_1300             jpg
# 25     226       SecurityCam_Ali_20250916_1745             jpg
# 26     227       SecurityCam_Kim_20250916_0840             jpg
# 27     228       SecurityCam_Kim_20250916_1630             jpg
# 28     229      SecurityCam_Chen_20250916_0850             jpg
# 29     230      SecurityCam_Chen_20250916_1130             jpg
# 30     231      SecurityCam_Chen_20250916_1300             jpg
# 31     232      SecurityCam_Chen_20250916_1700             jpg
# 32     233    SecurityCam_Mendez_20250916_0945             jpg
# 33     234    SecurityCam_Mendez_20250916_1715             jpg
# 34     235  SecurityCam_ODonnell_20250916_0810             jpg
# 35     236  SecurityCam_ODonnell_20250916_1230             jpg
# 36     237  SecurityCam_ODonnell_20250916_1330             jpg
# 37     238  SecurityCam_ODonnell_20250916_1800             jpg
# 38     239     SecurityCam_Brown_20250916_0900             jpg
# 39     240     SecurityCam_Brown_20250916_1730             jpg
# 40     241  SecurityCam_Yamamoto_20250916_0745             jpg
# 41     242  SecurityCam_Yamamoto_20250916_1145             jpg
# 42     243  SecurityCam_Yamamoto_20250916_1245             jpg
# 43     244  SecurityCam_Yamamoto_20250916_1645             jpg
# 44     245     SecurityCam_Lopez_20250916_0830             jpg
# 45     246     SecurityCam_Lopez_20250916_1200             jpg
# 46     247     SecurityCam_Lopez_20250916_1300             jpg
# 47     248     SecurityCam_Lopez_20250916_1700             jpg
#
#                                             ImageData ImageCategoryId  \
# 0   /9j/4AAQSkZJRgABAQEAYABgAAD/2wBDAAYEBQYFBAYGBQ...              16
# 1   /9j/4AAQSkZJRgABAQEAYABgAAD/2wBDAAYEBQYFBAYGBQ...              16
# 2   /9j/4AAQSkZJRgABAQEAYABgAAD/2wBDAAYEBQYFBAYGBQ...              16
# 3   /9j/4AAQSkZJRgABAQEAYABgAAD/2wBDAAYEBQYFBAYGBQ...              16
# 4   /9j/4AAQSkZJRgABAQEAYABgAAD/2wBDAAYEBQYFBAYGBQ...              16
# 5   /9j/4AAQSkZJRgABAQEAYABgAAD/2wBDAAYEBQYFBAYGBQ...              16
# 6   /9j/4AAQSkZJRgABAQEAYABgAAD/2wBDAAYEBQYFBAYGBQ...              16
# 7   /9j/4AAQSkZJRgABAQEAYABgAAD/2wBDAAYEBQYFBAYGBQ...              16
# 8   /9j/4AAQSkZJRgABAQEAYABgAAD/2wBDAAYEBQYFBAYGBQ...              16
# 9   /9j/4AAQSkZJRgABAQEAYABgAAD/2wBDAAYEBQYFBAYGBQ...              16
# 10  /9j/4AAQSkZJRgABAQEAYABgAAD/2wBDAAYEBQYFBAYGBQ...              16
# 11  /9j/4AAQSkZJRgABAQEAYABgAAD/2wBDAAYEBQYFBAYGBQ...              16
# 12  /9j/4AAQSkZJRgABAQEAYABgAAD/2wBDAAYEBQYFBAYGBQ...              16
# 13  /9j/4AAQSkZJRgABAQEAYABgAAD/2wBDAAYEBQYFBAYGBQ...              16
# 14  /9j/4AAQSkZJRgABAQEAYABgAAD/2wBDAAYEBQYFBAYGBQ...              16
# 15  /9j/4AAQSkZJRgABAQEAYABgAAD/2wBDAAYEBQYFBAYGBQ...              16
# 16  /9j/4AAQSkZJRgABAQEAYABgAAD/2wBDAAYEBQYFBAYGBQ...              16
# 17  /9j/4AAQSkZJRgABAQEAYABgAAD/2wBDAAYEBQYFBAYGBQ...              16
# 18  /9j/4AAQSkZJRgABAQEAYABgAAD/2wBDAAYEBQYFBAYGBQ...              16
# 19  /9j/4AAQSkZJRgABAQEAYABgAAD/2wBDAAYEBQYFBAYGBQ...              16
# 20  /9j/4AAQSkZJRgABAQEAYABgAAD/2wBDAAYEBQYFBAYGBQ...              16
# 21  /9j/4AAQSkZJRgABAQEAYABgAAD/2wBDAAYEBQYFBAYGBQ...              16
# 22  /9j/4AAQSkZJRgABAQEAYABgAAD/2wBDAAYEBQYFBAYGBQ...              16
# 23  /9j/4AAQSkZJRgABAQEAYABgAAD/2wBDAAYEBQYFBAYGBQ...              16
# 24  /9j/4AAQSkZJRgABAQEAYABgAAD/2wBDAAYEBQYFBAYGBQ...              16
# 25  /9j/4AAQSkZJRgABAQEAYABgAAD/2wBDAAYEBQYFBAYGBQ...              16
# 26  /9j/4AAQSkZJRgABAQEAYABgAAD/2wBDAAYEBQYFBAYGBQ...              16
# 27  /9j/4AAQSkZJRgABAQEAYABgAAD/2wBDAAYEBQYFBAYGBQ...              16
# 28  /9j/4AAQSkZJRgABAQEAYABgAAD/2wBDAAYEBQYFBAYGBQ...              16
# 29  /9j/4AAQSkZJRgABAQEAYABgAAD/2wBDAAYEBQYFBAYGBQ...              16
# 30  /9j/4AAQSkZJRgABAQEAYABgAAD/2wBDAAYEBQYFBAYGBQ...              16
# 31  /9j/4AAQSkZJRgABAQEAYABgAAD/2wBDAAYEBQYFBAYGBQ...              16
# 32  /9j/4AAQSkZJRgABAQEAYABgAAD/2wBDAAYEBQYFBAYGBQ...              16
# 33  /9j/4AAQSkZJRgABAQEAYABgAAD/2wBDAAYEBQYFBAYGBQ...              16
# 34  /9j/4AAQSkZJRgABAQEAYABgAAD/2wBDAAYEBQYFBAYGBQ...              16
# 35  /9j/4AAQSkZJRgABAQEAYABgAAD/2wBDAAYEBQYFBAYGBQ...              16
# 36  /9j/4AAQSkZJRgABAQEAYABgAAD/2wBDAAYEBQYFBAYGBQ...              16
# 37  /9j/4AAQSkZJRgABAQEAYABgAAD/2wBDAAYEBQYFBAYGBQ...              16
# 38  /9j/4AAQSkZJRgABAQEAYABgAAD/2wBDAAYEBQYFBAYGBQ...              16
# 39  /9j/4AAQSkZJRgABAQEAYABgAAD/2wBDAAYEBQYFBAYGBQ...              16
# 40  /9j/4AAQSkZJRgABAQEAYABgAAD/2wBDAAYEBQYFBAYGBQ...              16
# 41  /9j/4AAQSkZJRgABAQEAYABgAAD/2wBDAAYEBQYFBAYGBQ...              16
# 42  /9j/4AAQSkZJRgABAQEAYABgAAD/2wBDAAYEBQYFBAYGBQ...              16
# 43  /9j/4AAQSkZJRgABAQEAYABgAAD/2wBDAAYEBQYFBAYGBQ...              16
# 44  /9j/4AAQSkZJRgABAQEAYABgAAD/2wBDAAYEBQYFBAYGBQ...              16
# 45  /9j/4AAQSkZJRgABAQEAYABgAAD/2wBDAAYEBQYFBAYGBQ...              16
# 46  /9j/4AAQSkZJRgABAQEAYABgAAD/2wBDAAYEBQYFBAYGBQ...              16
# 47  /9j/4AAQSkZJRgABAQEAYABgAAD/2wBDAAYEBQYFBAYGBQ...              16
#
#    categoryId             categoryName
# 0          16  Security Camera Footage
# 1          16  Security Camera Footage
# 2          16  Security Camera Footage
# 3          16  Security Camera Footage
# 4          16  Security Camera Footage
# 5          16  Security Camera Footage
# 6          16  Security Camera Footage
# 7          16  Security Camera Footage
# 8          16  Security Camera Footage
# 9          16  Security Camera Footage
# 10         16  Security Camera Footage
# 11         16  Security Camera Footage
# 12         16  Security Camera Footage
# 13         16  Security Camera Footage
# 14         16  Security Camera Footage
# 15         16  Security Camera Footage
# 16         16  Security Camera Footage
# 17         16  Security Camera Footage
# 18         16  Security Camera Footage
# 19         16  Security Camera Footage
# 20         16  Security Camera Footage
# 21         16  Security Camera Footage
# 22         16  Security Camera Footage
# 23         16  Security Camera Footage
# 24         16  Security Camera Footage
# 25         16  Security Camera Footage
# 26         16  Security Camera Footage
# 27         16  Security Camera Footage
# 28         16  Security Camera Footage
# 29         16  Security Camera Footage
# 30         16  Security Camera Footage
# 31         16  Security Camera Footage
# 32         16  Security Camera Footage
# 33         16  Security Camera Footage
# 34         16  Security Camera Footage
# 35         16  Security Camera Footage
# 36         16  Security Camera Footage
# 37         16  Security Camera Footage
# 38         16  Security Camera Footage
# 39         16  Security Camera Footage
# 40         16  Security Camera Footage
# 41         16  Security Camera Footage
# 42         16  Security Camera Footage
# 43         16  Security Camera Footage
# 44         16  Security Camera Footage
# 45         16  Security Camera Footage
# 46         16  Security Camera Footage
# 47         16  Security Camera Footage
#
# [48 rows x 23 columns]
